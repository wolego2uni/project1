# %% [markdown]
# <a href="https://colab.research.google.com/github/wolego2uni/project1/blob/main/Simple_house_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using tensorflow to predict the price of houses based on a simple logic of 50k as base price and 50k per bedroom, i.e one bedroom 50+ 50k for the single room =100k and a two bedroom house will cost 150k and so on.
# In this case 50k is the constant and the price varies on the number of beds.
#
# This exercise is based on Introduction to tensorflow from coursera(deeplearning.ai)

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# GRADED FUNCTION: house_model
def house_model(y_new):
  xs =np.array([1,2,3, 4, 5, 6], dtype=int)
  ys =np.array([100,150,200,250,300,350], dtype=int)
  model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
  model.compile(optimizer='sgd', loss='mean_squared_error')
  model.fit(xs, ys, epochs=1300)
  return model.predict(y_new)[0]

# %%
prediction = int(house_model([7]))
print(prediction)
# Out:
# Epoch 1/1300
# 1/1 [==============================] - 0s 219ms/step - loss: 55701.2031
# Epoch 2/1300
# 1/1 [==============================] - 0s 4ms/step - loss: 25916.8027
# Epoch 3/1300
# 1/1 [==============================] - 0s 7ms/step - loss: 12130.6953
# Epoch 4/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 5749.0806
# Epoch 5/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 2794.4993
# Epoch 6/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 1426.0562
# Epoch 7/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 791.7335
# Epoch 8/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 497.1901
# Epoch 9/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 359.9142
# Epoch 10/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 295.4329
# Epoch 11/1300
# 1/1 [==============================] - 0s 3ms/step - loss: 264.6503
# Epoch 12/1300
# ...
